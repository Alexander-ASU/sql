# %% [markdown]
# ### Задание 1

# %% [markdown]
# Придумайте функции со следующими свойствами (в a) b) c) область определения X любая, какая вам удобна, главное - функция с нужными свойствами):
#
# a) бесконечное количество локальных экстремумов
#
# b) 2 локальных экстремума
#
# с) 3 локальных экстремума
#
# d*) область определения функции - 1 точка | y = 1

# %%
import matplotlib.pyplot as plt
import numpy as np
import pylab

from scipy.misc import derivative
from scipy.misc import electrocardiogram
from scipy.optimize import fmin, brute
from scipy.signal import find_peaks

# %%
def f(x):
    return np.sin(x)

# %% [markdown]
# a) бесконечное количество локальных экстремумов

# %%
# objective function

x0 = -5 # start from x = -5
xmin0 = fmin(f,x0)

x1 = -4 # start from x = -4
xmin1 = fmin(f,x1)

# plot the function
x = np.linspace(-15,15,100)
y = f(x)
pylab.plot(x,y)
# plot of x0 and the minimum found startin from x0
pylab.plot(xmin0, f(xmin0), 'bo')
# plot of x1 and the minimum found startin from x1
pylab.plot(xmin1, f(xmin1), 'ro')

pylab.axis([-15,15,-1.3,1.3])
pylab.show()
# Out:
# Optimization terminated successfully.
#          Current function value: -1.000000
#          Iterations: 18
#          Function evaluations: 36
# Optimization terminated successfully.
#          Current function value: -1.000000
#          Iterations: 18
#          Function evaluations: 36

# %% [markdown]
# b) 2 локальных экстремума

# %%
def f2(x):
    return 1/x-1

# %%
# objective function

x0 = -1 # start from x = -1
xmin0 = fmin(f2,x0)

x1 = -1 # start from x = -1
xmin1 = fmin(f2,x1)

# plot the function
x = np.linspace(-15,15,100)
y = f2(x)
pylab.plot(x,y)
# plot of x0 and the minimum found startin from x0
pylab.plot(xmin0, f2(xmin0), 'bo')
# plot of x1 and the minimum found startin from x1
pylab.plot(xmin1, f2(xmin1), 'ro')

pylab.axis([-20,20,-10,10])
pylab.show()
# Out:
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.

# %% [markdown]
# с) 3 локальных экстремума

# %%
def f3(x):
    return x**4 -11*x**2 + 2*x + 15

# %%
# objective function

x0 = -1 # start from x = -1
xmin0 = fmin(f3,x0)

x1 = -1 # start from x = -1
xmin1 = fmin(f3,x1)

# plot the function
x = np.linspace(-15,15,100)
y = f3(x)
pylab.plot(x,y)
# plot of x0 and the minimum found startin from x0
pylab.plot(xmin0, f3(xmin0), 'bo')
# plot of x1 and the minimum found startin from x1
pylab.plot(xmin1, f3(xmin1), 'ro')

pylab.axis([-10,10,-25,20])
pylab.show()
# Out:
# Optimization terminated successfully.
#          Current function value: -19.985022
#          Iterations: 18
#          Function evaluations: 36
# Optimization terminated successfully.
#          Current function value: -19.985022
#          Iterations: 18
#          Function evaluations: 36

# %% [markdown]
# d*) область определения функции - 1 точка | y = 1

# %%
def f4(x):
    return 1

# %%
# objective function

x0 = -1 # start from x = -1
xmin0 = fmin(f4,x0)

x1 = -1 # start from x = -1
xmin1 = fmin(f4,x1)

# plot the function
x = np.linspace(-15,15,100)
y = f4(x)
pylab.plot(x,y)
# plot of x0 and the minimum found startin from x0
pylab.plot(xmin0, f4(xmin0), 'bo')
# plot of x1 and the minimum found startin from x1
pylab.plot(xmin1, f4(xmin1), 'ro')

pylab.axis([-10,10,-25,20])
pylab.show()
# Out:
# Optimization terminated successfully.
#          Current function value: 1.000000
#          Iterations: 10
#          Function evaluations: 29
# Optimization terminated successfully.
#          Current function value: 1.000000
#          Iterations: 10
#          Function evaluations: 29
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-107-eb87231e5868> in <module>
#      10 x = np.linspace(-15,15,100)
#      11 y = f4(x)
# ---> 12 pylab.plot(x,y)
#      13 # plot of x0 and the minimum found startin from x0
#      14 pylab.plot(xmin0, f4(xmin0), 'bo')
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2811     return gca().plot(
#    2812         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2813         is not None else {}), **kwargs)
#    2814
#    2815
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, *args, **kwargs)
#    1609         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
#    1610
# -> 1611         for line in self._get_lines(*args, **kwargs):
#    1612             self.add_line(line)
#    1613             lines.append(line)
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in _grab_next_args(self, *args, **kwargs)
#     391                 this += args[0],
#     392                 args = args[1:]
# --> 393             yield from self._plot_args(this, kwargs)
#     394
#     395
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs)
#     368             x, y = index_of(tup[-1])
#     369
# --> 370         x, y = self._xy_from_xy(x, y)
#     371
#     372         if self.command == 'plot':
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in _xy_from_xy(self, x, y)
#     229         if x.shape[0] != y.shape[0]:
#     230             raise ValueError("x and y must have same first dimension, but "
# --> 231                              "have shapes {} and {}".format(x.shape, y.shape))
#     232         if x.ndim > 2 or y.ndim > 2:
#     233             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (100,) and (1,)

# %% [markdown]
# ### Задание 2:

# %% [markdown]
# Посчитайте 1-ую и 2-ую производные следующих функций (на бумажке:)):
#
# a) $f(x) = sin^2(2x+1)$
#
# b) $f(x) = ln(x^3+2sin(x))$ (выражение второй производной упрощать не нужно)

# %% [markdown]
# ### Задание 3:

# %% [markdown]
# Используя numpy, посчитайте значение 3-ей и 4-ой производных функций в точке:
#
# $f(x) = x^5+4sin(2x)+cos(3x+3)$ в точке $x=1$

# %%
def f5(x):
    return x**5 + 4 * np.sin(2*x) + np.cos(3*x + 3)

# %%
from scipy.misc import derivative
def f5(x):
    return x**5 + 4 * np.sin(2*x) + np.cos(3*x + 3)
derivative(f5, 1.0, dx=1e-6)
# Out:
# 2.509071801881646

# %%
from scipy.misc import derivative
def f5(x):
    return x**5 + 4 * np.sin(2*x) + np.cos(3*x + 3)
derivative(f5, 1.0, dx=1e-6, n=4)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-123-f9e6976e4a75> in <module>
#       2 def f5(x):
#       3     return x**5 + 4 * np.sin(2*x) + np.cos(3*x + 3)
# ----> 4 derivative(f5, 1.0, dx=1e-6, n=4)
#
# ~\Anaconda3\lib\site-packages\scipy\misc\common.py in derivative(func, x0, dx, n, args, order)
#      84     """
#      85     if order < n + 1:
# ---> 86         raise ValueError("'order' (the number of points used to compute the derivative), "
#      87                          "must be at least the derivative order 'n' + 1.")
#      88     if order % 2 == 0:
#
# ValueError: 'order' (the number of points used to compute the derivative), must be at least the derivative order 'n' + 1.
