# %% [markdown]
# Вы получили основные навыки обработки данных, теперь пора испытать их на практике. Сейчас вам предстоит заняться задачей классификации.
#
# Представлен датасет центра приюта животных, и вашей задачей будет обучить модель таким образом, чтобы  по определенным признакам была возможность максимально уверенно предсказать метки 'Adoption' и 'Transfer' (столбец “outcome_type”).
#
# Здесь вы вольны делать что угодно. Я хочу видеть от вас:
# 1. Проверка наличия/обработка пропусков
# 2. Проверьте взаимосвязи между признаками
# 3. Попробуйте создать свои признаки
# 4. Удалите лишние
# 5. Обратите внимание на текстовые столбцы. Подумайте, что можно извлечь полезного оттуда
# 6. Использование профайлера вам поможет.
# 7. Не забывайте, что у вас есть PCA (Метод главных компонент). Он может пригодиться.
#
# Вспомните о всем, что я говорил на предыдущих занятиях. Не все будет пригодится, но в жизни вам никто не будет говорить, что использовать :)
#
# Хорошим классификатором для этой задачи будет "Случайный лес" (https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html)
#
# Понимать суть работы "леса" не обязательно на данном этапе, но качество предсказаний будет выше, чем с линейным классификатором. (если желаете, вот гайд https://adataanalyst.com/scikit-learn/linear-classification-method/)
#
# Желаю успеха :)

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
import seaborn as sns
from matplotlib import pyplot as plt

data = pd.read_csv("aac_shelter_outcomes.csv")
data.head(20)
# Out:
#    age_upon_outcome animal_id animal_type  \
# 0           2 weeks   A684346         Cat
# 1            1 year   A666430         Dog
# 2            1 year   A675708         Dog
# 3           9 years   A680386         Dog
# 4          5 months   A683115       Other
# 5          4 months   A664462         Dog
# 6            1 year   A693700       Other
# 7           3 years   A692618         Dog
# 8           1 month   A685067         Cat
# 9          3 months   A678580         Cat
# 10           1 year   A675405         Cat
# 11          2 years   A673652         Dog
# 12         2 months   A677679         Dog
# 13          4 years   A640655         Dog
# 14          8 years   A690350         Dog
# 15          2 years   A680396         Dog
# 16           1 year   A674298         Dog
# 17          3 weeks   A670420         Cat
# 18         2 months   A692378         Dog
# 19         2 months   A684460         Cat
#
#                                    breed                color  \
# 0                 Domestic Shorthair Mix         Orange Tabby
# 1                             Beagle Mix          White/Brown
# 2                               Pit Bull           Blue/White
# 3                Miniature Schnauzer Mix                White
# 4                                Bat Mix                Brown
# 5                         Leonberger Mix          Brown/White
# 6                           Squirrel Mix                  Tan
# 7                Chihuahua Shorthair Mix                Brown
# 8                 Domestic Shorthair Mix     Blue Tabby/White
# 9                 Domestic Shorthair Mix          White/Black
# 10              Domestic Medium Hair Mix          Black/White
# 11                Papillon/Border Collie          Black/White
# 12        Chihuahua Shorthair/Pomeranian                Black
# 13  Miniature Schnauzer/Miniature Poodle                White
# 14                Labrador Retriever Mix                Black
# 15                       Rat Terrier Mix          White/Black
# 16                          Pit Bull Mix  Brown Brindle/White
# 17                Domestic Shorthair Mix          Black/White
# 18    German Shepherd/Labrador Retriever          Black/White
# 19                Domestic Shorthair Mix          Brown Tabby
#
#           date_of_birth             datetime            monthyear  \
# 0   2014-07-07T00:00:00  2014-07-22T16:04:00  2014-07-22T16:04:00
# 1   2012-11-06T00:00:00  2013-11-07T11:47:00  2013-11-07T11:47:00
# 2   2013-03-31T00:00:00  2014-06-03T14:20:00  2014-06-03T14:20:00
# 3   2005-06-02T00:00:00  2014-06-15T15:50:00  2014-06-15T15:50:00
# 4   2014-01-07T00:00:00  2014-07-07T14:04:00  2014-07-07T14:04:00
# 5   2013-06-03T00:00:00  2013-10-07T13:06:00  2013-10-07T13:06:00
# 6   2013-12-13T00:00:00  2014-12-13T12:20:00  2014-12-13T12:20:00
# 7   2011-11-23T00:00:00  2014-12-08T15:55:00  2014-12-08T15:55:00
# 8   2014-06-16T00:00:00  2014-08-14T18:45:00  2014-08-14T18:45:00
# 9   2014-03-26T00:00:00  2014-06-29T17:45:00  2014-06-29T17:45:00
# 10  2013-03-27T00:00:00  2014-03-28T14:55:00  2014-03-28T14:55:00
# 11  2012-02-28T00:00:00  2014-03-28T14:39:00  2014-03-28T14:39:00
# 12  2014-03-07T00:00:00  2014-05-26T19:10:00  2014-05-26T19:10:00
# 13  2009-04-27T00:00:00  2014-04-25T11:17:00  2014-04-25T11:17:00
# 14  2006-10-18T00:00:00  2014-10-26T18:20:00  2014-10-26T18:20:00
# 15  2012-06-02T00:00:00  2014-06-15T15:11:00  2014-06-15T15:11:00
# 16  2013-03-11T00:00:00  2014-04-16T12:51:00  2014-04-16T12:51:00
# 17  2013-12-16T00:00:00  2014-01-09T19:29:00  2014-01-09T19:29:00
# 18  2014-10-19T00:00:00  2014-12-21T18:20:00  2014-12-21T18:20:00
# 19  2014-06-02T00:00:00  2014-08-13T15:04:00  2014-08-13T15:04:00
#
#            name outcome_subtype     outcome_type sex_upon_outcome
# 0           NaN         Partner         Transfer      Intact Male
# 1          Lucy         Partner         Transfer    Spayed Female
# 2       *Johnny             NaN         Adoption    Neutered Male
# 3        Monday         Partner         Transfer    Neutered Male
# 4           NaN     Rabies Risk       Euthanasia          Unknown
# 5        *Edgar         Partner         Transfer      Intact Male
# 6           NaN       Suffering       Euthanasia          Unknown
# 7         *Ella         Partner         Transfer    Spayed Female
# 8          Lucy             NaN         Adoption    Intact Female
# 9        *Frida         Offsite         Adoption    Spayed Female
# 10  Stella Luna             NaN  Return to Owner    Spayed Female
# 11        Fancy         Partner         Transfer    Neutered Male
# 12         Kash          Foster         Adoption    Neutered Male
# 13        Sandy             NaN  Return to Owner    Spayed Female
# 14          Shy             NaN  Return to Owner    Neutered Male
# 15      *Truman         Partner         Transfer    Neutered Male
# 16        *Newt         Partner         Transfer    Neutered Male
# 17          NaN         Partner         Transfer      Intact Male
# 18      *Bonnie          Foster         Adoption    Spayed Female
# 19         Elsa             NaN         Adoption    Spayed Female

# %% [markdown]
# Выдвенем несколько гипотез. На решение оставить животное или забрать в большей тепени могут влиять параметры

# %%
data.describe()
# Out:
#        age_upon_outcome animal_id animal_type                   breed  \
# count             78248     78256       78256                   78256
# unique               46     70855           5                    2128
# top              1 year   A706536         Dog  Domestic Shorthair Mix
# freq              14355        11       44242                   23335
#
#               color        date_of_birth             datetime  \
# count         78256                78256                78256
# unique          525                 5869                64361
# top     Black/White  2014-05-05T00:00:00  2016-04-18T00:00:00
# freq           8153                  112                   39
#
#                   monthyear   name outcome_subtype outcome_type  \
# count                 78256  54370           35963        78244
# unique                64361  14574              19            9
# top     2016-04-18T00:00:00  Bella         Partner     Adoption
# freq                     39    344           19660        33112
#
#        sex_upon_outcome
# count             78254
# unique                5
# top       Neutered Male
# freq              27784

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78256 entries, 0 to 78255
# Data columns (total 12 columns):
# age_upon_outcome    78248 non-null object
# animal_id           78256 non-null object
# animal_type         78256 non-null object
# breed               78256 non-null object
# color               78256 non-null object
# date_of_birth       78256 non-null object
# datetime            78256 non-null object
# monthyear           78256 non-null object
# name                54370 non-null object
# outcome_subtype     35963 non-null object
# outcome_type        78244 non-null object
# sex_upon_outcome    78254 non-null object
# dtypes: object(12)
# memory usage: 7.2+ MB

# %%
data["age_upon_outcome"].unique()
# Out:
# array(['2 weeks', '1 year', '9 years', '5 months', '4 months', '3 years',
#        '1 month', '3 months', '2 years', '2 months', '4 years', '8 years',
#        '3 weeks', '8 months', '12 years', '7 years', '5 years', '6 years',
#        '5 days', '10 months', '4 weeks', '10 years', '2 days', '6 months',
#        '14 years', '11 months', '15 years', '7 months', '13 years',
#        '11 years', '16 years', '9 months', '3 days', '6 days', '4 days',
#        '5 weeks', '1 week', '1 day', '1 weeks', '0 years', '17 years',
#        '20 years', '18 years', '19 years', '22 years', '25 years', nan],
#       dtype=object)

# %%
data["age_upon_outcome"].value_counts()
# Out:
# 1 year       14355
# 2 years      11194
# 2 months      9213
# 3 years       5157
# 3 months      3442
# 1 month       3344
# 4 years       2990
# 5 years       2691
# 4 months      2425
# 5 months      1951
# 6 months      1897
# 6 years       1810
# 8 years       1554
# 7 years       1537
# 3 weeks       1467
# 2 weeks       1330
# 10 months     1204
# 4 weeks       1194
# 8 months      1178
# 10 years      1159
# 7 months       963
# 9 years        822
# 9 months       673
# 12 years       609
# 1 weeks        513
# 11 months      490
# 11 years       429
# 1 week         427
# 13 years       389
# 14 years       253
# 3 days         235
# 2 days         217
# 15 years       208
# 1 day          153
# 6 days         152
# 4 days         136
# 5 days         116
# 16 years       101
# 0 years         95
# 5 weeks         61
# 17 years        58
# 18 years        26
# 19 years        13
# 20 years        12
# 22 years         4
# 25 years         1
# Name: age_upon_outcome, dtype: int64

# %%
data.isnull().sum()
# Out:
# age_upon_outcome        8
# animal_id               0
# animal_type             0
# breed                   0
# color                   0
# date_of_birth           0
# datetime                0
# monthyear               0
# name                23886
# outcome_subtype     42293
# outcome_type           12
# sex_upon_outcome        2
# dtype: int64

# %%
data['age_upon_outcome'].fillna('1 year', inplace = True)

# %%
data.isnull().sum()
# Out:
# age_upon_outcome        0
# animal_id               0
# animal_type             0
# breed                   0
# color                   0
# date_of_birth           0
# datetime                0
# monthyear               0
# name                23886
# outcome_subtype     42293
# outcome_type           12
# sex_upon_outcome        2
# dtype: int64

# %%
data['sex_upon_outcome'].fillna('Neutered Male', inplace = True)

# %%
data.isnull().sum()
# Out:
# age_upon_outcome        0
# animal_id               0
# animal_type             0
# breed                   0
# color                   0
# date_of_birth           0
# datetime                0
# monthyear               0
# name                23886
# outcome_subtype     42293
# outcome_type           12
# sex_upon_outcome        0
# dtype: int64

# %%
data['outcome_type'].fillna('Adoption', inplace = True)

# %%
data.isnull().sum()
# Out:
# age_upon_outcome        0
# animal_id               0
# animal_type             0
# breed                   0
# color                   0
# date_of_birth           0
# datetime                0
# monthyear               0
# name                23886
# outcome_subtype     42293
# outcome_type            0
# sex_upon_outcome        0
# dtype: int64

# %%
data['outcome_subtype'].fillna('Partner', inplace = True)
data['name'].fillna('Bella', inplace = True)

# %%
data.isnull().sum()
# Out:
# age_upon_outcome    0
# animal_id           0
# animal_type         0
# breed               0
# color               0
# date_of_birth       0
# datetime            0
# monthyear           0
# name                0
# outcome_subtype     0
# outcome_type        0
# sex_upon_outcome    0
# dtype: int64

# %%
data.head()
# Out:
#   age_upon_outcome animal_id animal_type                    breed  \
# 0          2 weeks   A684346         Cat   Domestic Shorthair Mix
# 1           1 year   A666430         Dog               Beagle Mix
# 2           1 year   A675708         Dog                 Pit Bull
# 3          9 years   A680386         Dog  Miniature Schnauzer Mix
# 4         5 months   A683115       Other                  Bat Mix
#
#           color        date_of_birth             datetime  \
# 0  Orange Tabby  2014-07-07T00:00:00  2014-07-22T16:04:00
# 1   White/Brown  2012-11-06T00:00:00  2013-11-07T11:47:00
# 2    Blue/White  2013-03-31T00:00:00  2014-06-03T14:20:00
# 3         White  2005-06-02T00:00:00  2014-06-15T15:50:00
# 4         Brown  2014-01-07T00:00:00  2014-07-07T14:04:00
#
#              monthyear     name outcome_subtype outcome_type sex_upon_outcome
# 0  2014-07-22T16:04:00    Bella         Partner     Transfer      Intact Male
# 1  2013-11-07T11:47:00     Lucy         Partner     Transfer    Spayed Female
# 2  2014-06-03T14:20:00  *Johnny         Partner     Adoption    Neutered Male
# 3  2014-06-15T15:50:00   Monday         Partner     Transfer    Neutered Male
# 4  2014-07-07T14:04:00    Bella     Rabies Risk   Euthanasia          Unknown

# %% [markdown]
# Признаки datetime и monthyear не несут большой информации их можно удалить из датасета, а date_of_birth - избыточен, так как эта информация указана в age_upon_outcome,animal_id- не несет информации

# %%
data.drop(['datetime', 'monthyear', 'date_of_birth','animal_id'], axis='columns', inplace=True)

# %%
data.head(10)
# Out:
#   age_upon_outcome animal_type                    breed             color  \
# 0          2 weeks         Cat   Domestic Shorthair Mix      Orange Tabby
# 1           1 year         Dog               Beagle Mix       White/Brown
# 2           1 year         Dog                 Pit Bull        Blue/White
# 3          9 years         Dog  Miniature Schnauzer Mix             White
# 4         5 months       Other                  Bat Mix             Brown
# 5         4 months         Dog           Leonberger Mix       Brown/White
# 6           1 year       Other             Squirrel Mix               Tan
# 7          3 years         Dog  Chihuahua Shorthair Mix             Brown
# 8          1 month         Cat   Domestic Shorthair Mix  Blue Tabby/White
# 9         3 months         Cat   Domestic Shorthair Mix       White/Black
#
#       name outcome_subtype outcome_type sex_upon_outcome
# 0    Bella         Partner     Transfer      Intact Male
# 1     Lucy         Partner     Transfer    Spayed Female
# 2  *Johnny         Partner     Adoption    Neutered Male
# 3   Monday         Partner     Transfer    Neutered Male
# 4    Bella     Rabies Risk   Euthanasia          Unknown
# 5   *Edgar         Partner     Transfer      Intact Male
# 6    Bella       Suffering   Euthanasia          Unknown
# 7    *Ella         Partner     Transfer    Spayed Female
# 8     Lucy         Partner     Adoption    Intact Female
# 9   *Frida         Offsite     Adoption    Spayed Female

# %%
data['animal_type'].value_counts()
# Out:
# Dog          44242
# Cat          29422
# Other         4249
# Bird           334
# Livestock        9
# Name: animal_type, dtype: int64

# %%
data['color'].value_counts()
# Out:
# Black/White                  8153
# Black                        6602
# Brown Tabby                  4445
# Brown                        3486
# White                        2784
# Brown/White                  2444
# Tan/White                    2394
# Brown Tabby/White            2338
# Orange Tabby                 2180
# White/Black                  2100
# Blue/White                   2081
# Tricolor                     1982
# Tan                          1963
# Black/Tan                    1829
# White/Brown                  1577
# Black/Brown                  1532
# Brown Brindle/White          1353
# Tortie                       1340
# Calico                       1338
# Blue                         1326
# Brown/Black                  1323
# White/Tan                    1160
# Blue Tabby                   1130
# Orange Tabby/White           1095
# Red                          1029
# Red/White                     860
# Torbie                        845
# Brown Brindle                 715
# Tan/Black                     607
# Chocolate/White               597
#                              ...
# Orange Tabby/Black              1
# Brown Tabby/Black Brindle       1
# White/Lilac Point               1
# Black/Gold                      1
# Tortie/Tortie                   1
# Brown/Black Tabby               1
# Chocolate/Gold                  1
# Tortie Point/Blue               1
# Lynx Point/Blue                 1
# Cream/Brown Merle               1
# Brown/Pink                      1
# Green/Orange                    1
# Lynx Point/Brown Tabby          1
# Black Tabby/Gray                1
# Yellow Brindle/Blue             1
# Calico Point/Gray               1
# Chocolate/Gray                  1
# Gray Tabby/Orange               1
# Lynx Point/Tan                  1
# Black Smoke/Brown Tabby         1
# Liver/Brown Brindle             1
# Red/Gold                        1
# Red Tick/Brown Merle            1
# Yellow/Yellow                   1
# Tortie/Black Smoke              1
# Silver/Blue                     1
# Blue/Silver                     1
# Orange Tabby/Apricot            1
# Blue Merle/Cream                1
# Tortie/Blue Tabby               1
# Name: color, Length: 525, dtype: int64

# %%
#import re
#test = 'White/Lilac Point'
#rez = re.search(r"\/", test)
#print(rez.group())
def two_color(a):
    import re
    rez = re.search(r"\/", a)
    if rez is None:
        return 0
    else:
        return 1

# %%
data['two_color'] = data['color'].apply(two_color)

# %%
data.head()
# Out:
#   age_upon_outcome animal_type                    breed         color  \
# 0          2 weeks         Cat   Domestic Shorthair Mix  Orange Tabby
# 1           1 year         Dog               Beagle Mix   White/Brown
# 2           1 year         Dog                 Pit Bull    Blue/White
# 3          9 years         Dog  Miniature Schnauzer Mix         White
# 4         5 months       Other                  Bat Mix         Brown
#
#       name outcome_subtype outcome_type sex_upon_outcome  two_color
# 0    Bella         Partner     Transfer      Intact Male          0
# 1     Lucy         Partner     Transfer    Spayed Female          1
# 2  *Johnny         Partner     Adoption    Neutered Male          1
# 3   Monday         Partner     Transfer    Neutered Male          0
# 4    Bella     Rabies Risk   Euthanasia          Unknown          0

# %%
def mix_breed(a):
    import re
    rez1 = re.search(r"Mix", a)
    if rez1 is None:
        return 0
    else:
        return 1

# %%
data['mix_breed'] = data['breed'].apply(mix_breed)

# %%
data.head(15)
# Out:
#    age_upon_outcome animal_type                                 breed  \
# 0           2 weeks         Cat                Domestic Shorthair Mix
# 1            1 year         Dog                            Beagle Mix
# 2            1 year         Dog                              Pit Bull
# 3           9 years         Dog               Miniature Schnauzer Mix
# 4          5 months       Other                               Bat Mix
# 5          4 months         Dog                        Leonberger Mix
# 6            1 year       Other                          Squirrel Mix
# 7           3 years         Dog               Chihuahua Shorthair Mix
# 8           1 month         Cat                Domestic Shorthair Mix
# 9          3 months         Cat                Domestic Shorthair Mix
# 10           1 year         Cat              Domestic Medium Hair Mix
# 11          2 years         Dog                Papillon/Border Collie
# 12         2 months         Dog        Chihuahua Shorthair/Pomeranian
# 13          4 years         Dog  Miniature Schnauzer/Miniature Poodle
# 14          8 years         Dog                Labrador Retriever Mix
#
#                color         name outcome_subtype     outcome_type  \
# 0       Orange Tabby        Bella         Partner         Transfer
# 1        White/Brown         Lucy         Partner         Transfer
# 2         Blue/White      *Johnny         Partner         Adoption
# 3              White       Monday         Partner         Transfer
# 4              Brown        Bella     Rabies Risk       Euthanasia
# 5        Brown/White       *Edgar         Partner         Transfer
# 6                Tan        Bella       Suffering       Euthanasia
# 7              Brown        *Ella         Partner         Transfer
# 8   Blue Tabby/White         Lucy         Partner         Adoption
# 9        White/Black       *Frida         Offsite         Adoption
# 10       Black/White  Stella Luna         Partner  Return to Owner
# 11       Black/White        Fancy         Partner         Transfer
# 12             Black         Kash          Foster         Adoption
# 13             White        Sandy         Partner  Return to Owner
# 14             Black          Shy         Partner  Return to Owner
#
#    sex_upon_outcome  two_color  mix_breed
# 0       Intact Male          0          1
# 1     Spayed Female          1          1
# 2     Neutered Male          1          0
# 3     Neutered Male          0          1
# 4           Unknown          0          1
# 5       Intact Male          1          1
# 6           Unknown          0          1
# 7     Spayed Female          0          1
# 8     Intact Female          1          1
# 9     Spayed Female          1          1
# 10    Spayed Female          1          1
# 11    Neutered Male          1          0
# 12    Neutered Male          0          0
# 13    Spayed Female          0          0
# 14    Neutered Male          0          1

# %%
from sklearn.metrics import classification_report, accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
y = data['outcome_type']
X = data.drop(['outcome_type'], axis=1)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=30)
from sklearn.ensemble import RandomForestClassifier

# Создаём модель леса из сотни деревьев
model = RandomForestClassifier(n_estimators=100, 
                               bootstrap = True,
                               max_features = 'sqrt')
# Обучаем на тренировочных данных
model.fit(X_train, y_train)

# Действующая классификация
rf_predictions = model.predict(X_test)
# Вероятности для каждого класса
rf_probs = model.predict_proba(X_test)[:, 1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-195-9c05e3d05aea> in <module>
#      10                                max_features = 'sqrt')
#      11 # Обучаем на тренировочных данных
# ---> 12 model.fit(X_train, y_train)
#      13
#      14 # Действующая классификация
#
# ~\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py in fit(self, X, y, sample_weight)
#     248
#     249         # Validate or convert input data
# --> 250         X = check_array(X, accept_sparse="csc", dtype=DTYPE)
#     251         y = check_array(y, accept_sparse='csc', ensure_2d=False, dtype=None)
#     252         if sample_weight is not None:
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     525             try:
#     526                 warnings.simplefilter('error', ComplexWarning)
# --> 527                 array = np.asarray(array, dtype=dtype, order=order)
#     528             except ComplexWarning:
#     529                 raise ValueError("Complex data not supported\n"
#
# ~\Anaconda3\lib\site-packages\numpy\core\numeric.py in asarray(a, dtype, order)
#     499
#     500     """
# --> 501     return array(a, dtype, copy=False, order=order)
#     502
#     503
#
# ValueError: could not convert string to float: '4 years'
